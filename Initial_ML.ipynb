# %%
import sklearn.datasets
import matplotlib.pyplot as plt

x,y = sklearn.datasets.make_regression(n_samples=100, n_features=1, n_informative=1, noise=10, coef=False, random_state=2021)

print('x,y = {:.4f},{:.4f}'.format(x[0][0], y[0]))
# Out:
# x,y = 0.1028,-16.6727
